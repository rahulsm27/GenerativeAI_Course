# %%
"""
STEP 1

# Induction 

# Python prerequsites
#  NLP
        ML
            BOW, TfiDF, One Hot Encoding, WOrd2Vec, Avg WOrd2Vec, n grams

        DL
            RNN, LSTM, RNN, GRN, BiLSTM,
            Encoder, Decoder, Transformer, BERT


"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""
STEP 2  

Generative AI -> Projects
 How LLM is trained
Projects -> OpenAI, LLAM2
Vector DB -> Cassandra DB

Frame work Langchain, LLAMA index
 
MLOPS-> Deployment - Azure, AWS, GCP, hugging face

Google Gemini -> Multimodel

"""

# %%
"""

LLM -> Large Language Model
LIM -> Large Image Model


"""
